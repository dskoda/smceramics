# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('lattice.xlsx')

# %% [markdown]
# ## Plotting the lattice parameter with respect to the composition at a fixed temperature

# %%
data_T = data[data['T(C)'] == 25]

# %%
data_T.plot(kind='scatter', x='Zr', y='a (A)')
plt.show()
